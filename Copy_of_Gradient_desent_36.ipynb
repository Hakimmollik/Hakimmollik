# %% [markdown]
# <a href="https://colab.research.google.com/github/Hakimmollik/Hakimmollik/blob/main/Copy_of_Gradient_desent_36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Created dataset

x, y = make_regression(
    n_samples = 100,
    n_features = 1,
    n_informative = 1,
    n_targets = 1,
    random_state = 42
)

# %%
# plot

plt.scatter(x, y)
plt.show()

# %%
# Train test split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.2, random_state=42
)

# %%
# LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Slope number used

print("m :", lr.coef_)
print("b :", lr.intercept_)
# Out:
# m : [41.74110031]
# b : 0.0

# %%
# Predict number used

y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 27.03523224, -19.59637744, -26.92800839,   4.63003094,
#        -73.59123598,  15.0950856 ,  56.61095108, -13.67697853,
#         10.8967343 ,   8.21720459,  38.20989162, -12.17561807,
#        -28.25546912, -22.72313391, -16.0737581 ,  32.03357001,
#         20.73339529,  25.53204133, -12.48089581, -25.11589606])

# %%
mean = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

# %%
print("Mean squared error:", mean)

print("\n")

print("R2 Score:", r2)
# Out:
# Mean squared error: 2.749180254695226e-29
#
#
# R2 Score: 1.0

# %%
# Class

class GDRegressor:

  def __init__(self, learning_rate, epochs):
    self.m = 41.74110031
    self.b = -120
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self, x, y):
    for i in range(self.epochs):
      loss_slope_b = -2 * np.sum(y -(self.m * x . ravel() - self.b))
      self.b = self.b - (self.lr * loss_slope_b)

      print(f"m = {self.m}, b = {self.b}")


  def predict(self, x):
    return self.m * x + self.b

# %%
gd = GDRegressor(0.001, 50)
gd.fit(x_train, y_train)
# Out:
# m = 41.74110031, b = -139.2000000000986
# m = 41.74110031, b = -161.47200000021297
# m = 41.74110031, b = -187.30752000034565
# m = 41.74110031, b = -217.27672320049953
# m = 41.74110031, b = -252.04099891267805
# m = 41.74110031, b = -292.36755873880514
# m = 41.74110031, b = -339.1463681371126
# m = 41.74110031, b = -393.4097870391492
# m = 41.74110031, b = -456.35535296551166
# m = 41.74110031, b = -529.3722094400921
# m = 41.74110031, b = -614.0717629506055
# m = 41.74110031, b = -712.323245022801
# m = 41.74110031, b = -826.2949642265477
# m = 41.74110031, b = -958.502158502894
# m = 41.74110031, b = -1111.8625038634557
# m = 41.74110031, b = -1289.7605044817071
# m = 41.74110031, b = -1496.122185198879
# m = 41.74110031, b = -1735.5017348307981
# m = 41.74110031, b = -2013.1820124038245
# m = 41.74110031, b = -2335.291134388535
# m = 41.74110031, b = -2708.937715890799
# m = 41.74110031, b = -3142.3677504334255
# m = 41.74110031, b = -3645.146590502872
# ...

# %%
# Plot

plt.figure(figsize=(8,6))
plt.scatter(x_train, y_train, color = 'blue', label='Actual Data')
plt.plot(x_train, color= 'blue', label='GDRegressor')
plt.title("Linear Regression With GDRegressor")
plt.xlabel(x)
plt.ylabel(y)
plt.legend()
plt.grid(True)
plt.show()
